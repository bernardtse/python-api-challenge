# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 577

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = city_url = url + "units=" + units + "&appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]  

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})    

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | margaret river
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | irymple
# Processing Record 7 of Set 1 | whitehorse
# Processing Record 8 of Set 1 | hawaiian paradise park
# Processing Record 9 of Set 1 | rahachow
# Processing Record 10 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 11 of Set 1 | mizque
# Processing Record 12 of Set 1 | palikir - national government center
# Processing Record 13 of Set 1 | aasiaat
# Processing Record 14 of Set 1 | wailua homesteads
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | adamstown
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | stanley
# Processing Record 19 of Set 1 | guelendeng
# Processing Record 20 of Set 1 | jinchang
# Processing Record 21 of Set 1 | kulia village
# City not found. Skipping...
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | talara
# Processing Record 24 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 1 | tolanaro
# Processing Record 26 of Set 1 | santiago de cao
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | bilibino
# Processing Record 30 of Set 1 | lazaro cardenas
# Processing Record 31 of Set 1 | forster
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | mpophomeni
# Processing Record 34 of Set 1 | san patricio
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | zaozersk
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | olonkinbyen
# Processing Record 41 of Set 1 | edinburgh of the seven seas
# Processing Record 42 of Set 1 | encantado
# Processing Record 43 of Set 1 | moranbah
# Processing Record 44 of Set 1 | puerto natales
# Processing Record 45 of Set 1 | amalapuram
# Processing Record 46 of Set 1 | luanda
# Processing Record 47 of Set 1 | yorosso
# Processing Record 48 of Set 1 | bardai
# Processing Record 49 of Set 1 | tura
# Processing Record 50 of Set 1 | sibolga
# Processing Record 0 of Set 2 | pekan
# Processing Record 1 of Set 2 | port lincoln
# Processing Record 2 of Set 2 | pandan
# Processing Record 3 of Set 2 | ipatovo
# Processing Record 4 of Set 2 | talnakh
# Processing Record 5 of Set 2 | nar'yan-mar
# Processing Record 6 of Set 2 | arkhangel'sk
# Processing Record 7 of Set 2 | kudahuvadhoo
# Processing Record 8 of Set 2 | ilulissat
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | prince george
# Processing Record 11 of Set 2 | blackmans bay
# Processing Record 12 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 13 of Set 2 | kavaratti
# Processing Record 14 of Set 2 | usogorsk
# Processing Record 15 of Set 2 | maxixe
# Processing Record 16 of Set 2 | crucecita
# Processing Record 17 of Set 2 | hasaki
# Processing Record 18 of Set 2 | invercargill
# Processing Record 19 of Set 2 | huai yot
# Processing Record 20 of Set 2 | belmonte
# Processing Record 21 of Set 2 | iqaluit
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | susuman
# Processing Record 24 of Set 2 | villa gesell
# Processing Record 25 of Set 2 | minas de marcona
# Processing Record 26 of Set 2 | berdigestyakh
# Processing Record 27 of Set 2 | ust-nera
# Processing Record 28 of Set 2 | timbuktu
# Processing Record 29 of Set 2 | amper
# Processing Record 30 of Set 2 | christchurch
# Processing Record 31 of Set 2 | paimio
# Processing Record 32 of Set 2 | yeniseysk
# Processing Record 33 of Set 2 | changyon
# Processing Record 34 of Set 2 | modasa
# Processing Record 35 of Set 2 | enewetak
# Processing Record 36 of Set 2 | la junta
# Processing Record 37 of Set 2 | grande-synthe
# Processing Record 38 of Set 2 | el calafate
# Processing Record 39 of Set 2 | marsh harbour
# Processing Record 40 of Set 2 | uturoa
# Processing Record 41 of Set 2 | papatowai
# Processing Record 42 of Set 2 | oualidia
# City not found. Skipping...
# Processing Record 43 of Set 2 | xilin hot
# Processing Record 44 of Set 2 | fortuna
# Processing Record 45 of Set 2 | chonchi
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | laojunmiao
# Processing Record 48 of Set 2 | yellowknife
# Processing Record 49 of Set 2 | port elizabeth
# Processing Record 0 of Set 3 | fada
# Processing Record 1 of Set 3 | chandler
# Processing Record 2 of Set 3 | birao
# Processing Record 3 of Set 3 | pisco
# Processing Record 4 of Set 3 | luderitz
# Processing Record 5 of Set 3 | tvoroyri
# Processing Record 6 of Set 3 | daokou
# Processing Record 7 of Set 3 | san pedro pochutla
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | sandnessjoen
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | taroa
# Processing Record 12 of Set 3 | la passe
# Processing Record 13 of Set 3 | iskateley
# Processing Record 14 of Set 3 | chardara
# Processing Record 15 of Set 3 | saint-pierre
# Processing Record 16 of Set 3 | vila franca do campo
# Processing Record 17 of Set 3 | college
# Processing Record 18 of Set 3 | shahrak
# Processing Record 19 of Set 3 | tazovsky
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | saint-francois
# Processing Record 22 of Set 3 | utrik
# Processing Record 23 of Set 3 | roccella ionica
# Processing Record 24 of Set 3 | timmins
# Processing Record 25 of Set 3 | kapa'a
# Processing Record 26 of Set 3 | hirara
# Processing Record 27 of Set 3 | puerto armuelles
# Processing Record 28 of Set 3 | kibre mengist
# Processing Record 29 of Set 3 | mount isa
# Processing Record 30 of Set 3 | porto-vecchio
# Processing Record 31 of Set 3 | nyagan
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | yilan
# Processing Record 34 of Set 3 | inhambane
# Processing Record 35 of Set 3 | lagunillas
# Processing Record 36 of Set 3 | kristiansund
# Processing Record 37 of Set 3 | klyuchi
# Processing Record 38 of Set 3 | miles city
# Processing Record 39 of Set 3 | kalaswala
# Processing Record 40 of Set 3 | nalut
# Processing Record 41 of Set 3 | abepura
# Processing Record 42 of Set 3 | kokoda
# Processing Record 43 of Set 3 | rikaze
# Processing Record 44 of Set 3 | keflavik
# Processing Record 45 of Set 3 | east london
# Processing Record 46 of Set 3 | west island
# Processing Record 47 of Set 3 | ribeira brava
# Processing Record 48 of Set 3 | khanty-mansiysk
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 0 of Set 4 | quang ngai
# Processing Record 1 of Set 4 | swakopmund
# Processing Record 2 of Set 4 | lihue
# Processing Record 3 of Set 4 | rawson
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | znamenskoye
# Processing Record 6 of Set 4 | dudinka
# Processing Record 7 of Set 4 | nueva gerona
# Processing Record 8 of Set 4 | chernyshevskiy
# Processing Record 9 of Set 4 | babu
# Processing Record 10 of Set 4 | ancud
# Processing Record 11 of Set 4 | flying fish cove
# Processing Record 12 of Set 4 | mosfellsbaer
# Processing Record 13 of Set 4 | kinkala
# Processing Record 14 of Set 4 | qaqortoq
# Processing Record 15 of Set 4 | saipan
# Processing Record 16 of Set 4 | weno
# Processing Record 17 of Set 4 | south hedland
# Processing Record 18 of Set 4 | tomah
# Processing Record 19 of Set 4 | tank
# Processing Record 20 of Set 4 | chifeng
# Processing Record 21 of Set 4 | richards bay
# Processing Record 22 of Set 4 | jamalpur
# Processing Record 23 of Set 4 | san antonio de pale
# Processing Record 24 of Set 4 | manismata
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | afaahiti
# Processing Record 27 of Set 4 | howard springs
# Processing Record 28 of Set 4 | udachny
# Processing Record 29 of Set 4 | port mathurin
# Processing Record 30 of Set 4 | mandalgovi
# Processing Record 31 of Set 4 | umm kaddadah
# Processing Record 32 of Set 4 | shendi
# Processing Record 33 of Set 4 | nikolayevsk-on-amure
# Processing Record 34 of Set 4 | kapuskasing
# Processing Record 35 of Set 4 | kongolo
# Processing Record 36 of Set 4 | winejok
# City not found. Skipping...
# Processing Record 37 of Set 4 | lamba
# Processing Record 38 of Set 4 | kone
# Processing Record 39 of Set 4 | aginskoye
# Processing Record 40 of Set 4 | port macquarie
# Processing Record 41 of Set 4 | isafjordur
# Processing Record 42 of Set 4 | nantucket
# Processing Record 43 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 44 of Set 4 | atafu village
# Processing Record 45 of Set 4 | chuhar jamali
# Processing Record 46 of Set 4 | kangding
# Processing Record 47 of Set 4 | lata
# Processing Record 48 of Set 4 | vorgashor
# Processing Record 49 of Set 4 | jalai nur
# Processing Record 0 of Set 5 | pingliang
# Processing Record 1 of Set 5 | champerico
# Processing Record 2 of Set 5 | itaituba
# Processing Record 3 of Set 5 | paita
# Processing Record 4 of Set 5 | aral
# Processing Record 5 of Set 5 | turkmenbasy
# Processing Record 6 of Set 5 | san rafael
# Processing Record 7 of Set 5 | boa vista
# Processing Record 8 of Set 5 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 9 of Set 5 | gadzhiyevo
# Processing Record 10 of Set 5 | nuuk
# Processing Record 11 of Set 5 | ujhani
# Processing Record 12 of Set 5 | sorong
# Processing Record 13 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 14 of Set 5 | ellsworth
# Processing Record 15 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 16 of Set 5 | jaguaruna
# Processing Record 17 of Set 5 | vuktyl
# Processing Record 18 of Set 5 | puerto gaitan
# Processing Record 19 of Set 5 | lae
# Processing Record 20 of Set 5 | acarau
# Processing Record 21 of Set 5 | hotan
# Processing Record 22 of Set 5 | barda
# Processing Record 23 of Set 5 | isangel
# Processing Record 24 of Set 5 | hilo
# Processing Record 25 of Set 5 | onguday
# Processing Record 26 of Set 5 | vanino
# Processing Record 27 of Set 5 | itubera
# Processing Record 28 of Set 5 | guangyuan
# Processing Record 29 of Set 5 | vadso
# Processing Record 30 of Set 5 | colonia
# Processing Record 31 of Set 5 | gulf shores
# Processing Record 32 of Set 5 | bridgetown
# Processing Record 33 of Set 5 | hungnam
# Processing Record 34 of Set 5 | aripuana
# Processing Record 35 of Set 5 | cadale
# Processing Record 36 of Set 5 | pechora
# Processing Record 37 of Set 5 | ola
# Processing Record 38 of Set 5 | labrador city
# Processing Record 39 of Set 5 | nyrob
# Processing Record 40 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 41 of Set 5 | kroya
# Processing Record 42 of Set 5 | tampere
# Processing Record 43 of Set 5 | at taj
# Processing Record 44 of Set 5 | the pas
# Processing Record 45 of Set 5 | egilsstadir
# Processing Record 46 of Set 5 | washington
# Processing Record 47 of Set 5 | tongchuanshi
# Processing Record 48 of Set 5 | anadyr
# Processing Record 49 of Set 5 | constantia
# Processing Record 0 of Set 6 | guerrero negro
# Processing Record 1 of Set 6 | salaga
# Processing Record 2 of Set 6 | sao tome
# Processing Record 3 of Set 6 | souillac
# Processing Record 4 of Set 6 | ulladulla
# Processing Record 5 of Set 6 | kataragama
# City not found. Skipping...
# Processing Record 6 of Set 6 | badger
# Processing Record 7 of Set 6 | kingston
# Processing Record 8 of Set 6 | alice springs
# Processing Record 9 of Set 6 | ak-suu
# Processing Record 10 of Set 6 | griffith
# Processing Record 11 of Set 6 | chongwe
# Processing Record 12 of Set 6 | jemna
# Processing Record 13 of Set 6 | piti village
# Processing Record 14 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 15 of Set 6 | alta sierra
# Processing Record 16 of Set 6 | ta`u
# Processing Record 17 of Set 6 | sur
# Processing Record 18 of Set 6 | mahdia
# Processing Record 19 of Set 6 | hobyo
# Processing Record 20 of Set 6 | vilyuchinsk
# Processing Record 21 of Set 6 | quellon
# Processing Record 22 of Set 6 | aden
# Processing Record 23 of Set 6 | nadi
# Processing Record 24 of Set 6 | remire-montjoly
# Processing Record 25 of Set 6 | bikenibeu village
# Processing Record 26 of Set 6 | mareeba
# Processing Record 27 of Set 6 | college station
# Processing Record 28 of Set 6 | peterhof
# Processing Record 29 of Set 6 | smidovich
# Processing Record 30 of Set 6 | mizdah
# Processing Record 31 of Set 6 | suva
# Processing Record 32 of Set 6 | lodja
# Processing Record 33 of Set 6 | caleta de carquin
# Processing Record 34 of Set 6 | whakatane
# Processing Record 35 of Set 6 | the dalles
# Processing Record 36 of Set 6 | greymouth
# Processing Record 37 of Set 6 | kailua-kona
# Processing Record 38 of Set 6 | noshiro
# Processing Record 39 of Set 6 | west bay
# Processing Record 40 of Set 6 | siler city
# Processing Record 41 of Set 6 | saint-georges
# Processing Record 42 of Set 6 | lusaka
# Processing Record 43 of Set 6 | duba
# Processing Record 44 of Set 6 | navas de san juan
# Processing Record 45 of Set 6 | st. john's
# Processing Record 46 of Set 6 | seven pagodas
# Processing Record 47 of Set 6 | vorkuta
# Processing Record 48 of Set 6 | tinajo
# Processing Record 49 of Set 6 | papao
# Processing Record 0 of Set 7 | mersing
# Processing Record 1 of Set 7 | port glaud
# City not found. Skipping...
# Processing Record 2 of Set 7 | bondoukou
# Processing Record 3 of Set 7 | northam
# Processing Record 4 of Set 7 | yeovil
# Processing Record 5 of Set 7 | itoman
# Processing Record 6 of Set 7 | sitka
# Processing Record 7 of Set 7 | uttar char fasson
# Processing Record 8 of Set 7 | greenville
# Processing Record 9 of Set 7 | boca chica
# Processing Record 10 of Set 7 | juhaynah
# Processing Record 11 of Set 7 | santa ana
# Processing Record 12 of Set 7 | takoradi
# Processing Record 13 of Set 7 | castillos
# Processing Record 14 of Set 7 | selfoss
# Processing Record 15 of Set 7 | bubaque
# Processing Record 16 of Set 7 | falkoping
# City not found. Skipping...
# Processing Record 17 of Set 7 | lerwick
# Processing Record 18 of Set 7 | port alfred
# Processing Record 19 of Set 7 | westport
# Processing Record 20 of Set 7 | rongelap
# Processing Record 21 of Set 7 | nicoya
# Processing Record 22 of Set 7 | nagasaki
# Processing Record 23 of Set 7 | nukunonu
# City not found. Skipping...
# Processing Record 24 of Set 7 | kill devil hills
# Processing Record 25 of Set 7 | mount gambier
# Processing Record 26 of Set 7 | micheweni
# Processing Record 27 of Set 7 | nova vicosa
# Processing Record 28 of Set 7 | altay
# Processing Record 29 of Set 7 | holualoa
# Processing Record 30 of Set 7 | el nido
# Processing Record 31 of Set 7 | lompoc
# Processing Record 32 of Set 7 | camiri
# Processing Record 33 of Set 7 | cox's bazar
# Processing Record 34 of Set 7 | aykhal
# Processing Record 35 of Set 7 | broken hill
# Processing Record 36 of Set 7 | yuzhno-kurilsk
# Processing Record 37 of Set 7 | sakakah
# Processing Record 38 of Set 7 | loen
# Processing Record 39 of Set 7 | tlapa de comonfort
# Processing Record 40 of Set 7 | mossel bay
# Processing Record 41 of Set 7 | karratha
# Processing Record 42 of Set 7 | okondja
# Processing Record 43 of Set 7 | serhetabat
# Processing Record 44 of Set 7 | lautoka
# Processing Record 45 of Set 7 | nguruka
# Processing Record 46 of Set 7 | batesville
# Processing Record 47 of Set 7 | bayanhongor
# Processing Record 48 of Set 7 | bodo
# Processing Record 49 of Set 7 | ciudad victoria
# Processing Record 0 of Set 8 | seme
# Processing Record 1 of Set 8 | wailea
# Processing Record 2 of Set 8 | gutao
# Processing Record 3 of Set 8 | binbrook
# Processing Record 4 of Set 8 | punta del este
# Processing Record 5 of Set 8 | perry
# Processing Record 6 of Set 8 | albertina
# Processing Record 7 of Set 8 | barakani
# Processing Record 8 of Set 8 | nanpiao
# Processing Record 9 of Set 8 | nishinoomote
# Processing Record 10 of Set 8 | sinop
# Processing Record 11 of Set 8 | quiindy
# Processing Record 12 of Set 8 | mogocha
# Processing Record 13 of Set 8 | cabo san lucas
# Processing Record 14 of Set 8 | chantonnay
# Processing Record 15 of Set 8 | upington
# Processing Record 16 of Set 8 | mejit
# Processing Record 17 of Set 8 | solleftea
# Processing Record 18 of Set 8 | kerikeri
# Processing Record 19 of Set 8 | mombaca
# Processing Record 20 of Set 8 | madalena
# Processing Record 21 of Set 8 | ngorongoro
# Processing Record 22 of Set 8 | gokwe
# Processing Record 23 of Set 8 | tangalle
# Processing Record 24 of Set 8 | palmer
# Processing Record 25 of Set 8 | benguela
# Processing Record 26 of Set 8 | happy valley-goose bay
# Processing Record 27 of Set 8 | vikhorevka
# Processing Record 28 of Set 8 | axim
# Processing Record 29 of Set 8 | champagnole
# Processing Record 30 of Set 8 | lingdong
# Processing Record 31 of Set 8 | pontevedra
# Processing Record 32 of Set 8 | itamaraca
# Processing Record 33 of Set 8 | auki
# Processing Record 34 of Set 8 | hamilton
# Processing Record 35 of Set 8 | don luan
# Processing Record 36 of Set 8 | cabedelo
# Processing Record 37 of Set 8 | divinopolis
# Processing Record 38 of Set 8 | yeraliyev
# Processing Record 39 of Set 8 | rabigh
# Processing Record 40 of Set 8 | mata-utu
# Processing Record 41 of Set 8 | soufriere
# Processing Record 42 of Set 8 | zalanga
# Processing Record 43 of Set 8 | rostovka
# Processing Record 44 of Set 8 | dakoro
# Processing Record 45 of Set 8 | lethbridge
# Processing Record 46 of Set 8 | okhotsk
# Processing Record 47 of Set 8 | yaring
# Processing Record 48 of Set 8 | timimoun
# Processing Record 49 of Set 8 | tsiombe
# Processing Record 0 of Set 9 | hadibu
# Processing Record 1 of Set 9 | mongoumba
# Processing Record 2 of Set 9 | nikki
# Processing Record 3 of Set 9 | dryden
# Processing Record 4 of Set 9 | shitanjing
# Processing Record 5 of Set 9 | bileh savar
# City not found. Skipping...
# Processing Record 6 of Set 9 | meiktila
# Processing Record 7 of Set 9 | fort st. john
# Processing Record 8 of Set 9 | kawthoung
# City not found. Skipping...
# Processing Record 9 of Set 9 | duc trong
# City not found. Skipping...
# Processing Record 10 of Set 9 | baie-comeau
# Processing Record 11 of Set 9 | ayutla
# Processing Record 12 of Set 9 | ruiz
# Processing Record 13 of Set 9 | nova sintra
# Processing Record 14 of Set 9 | trinity beach
# Processing Record 15 of Set 9 | cortazar
# Processing Record 16 of Set 9 | cill airne
# Processing Record 17 of Set 9 | jawf al maqbabah
# Processing Record 18 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 19 of Set 9 | vernon
# Processing Record 20 of Set 9 | ceres
# Processing Record 21 of Set 9 | nieuw amsterdam
# Processing Record 22 of Set 9 | crane
# Processing Record 23 of Set 9 | siem reap
# Processing Record 24 of Set 9 | rio grande
# Processing Record 25 of Set 9 | queenstown
# Processing Record 26 of Set 9 | ypsonas
# Processing Record 27 of Set 9 | howrah
# Processing Record 28 of Set 9 | kudat
# Processing Record 29 of Set 9 | sabha
# Processing Record 30 of Set 9 | nouadhibou
# Processing Record 31 of Set 9 | shimokizukuri
# Processing Record 32 of Set 9 | geraldton
# Processing Record 33 of Set 9 | port saint john's
# Processing Record 34 of Set 9 | kruisfontein
# Processing Record 35 of Set 9 | lillesand
# Processing Record 36 of Set 9 | cide
# Processing Record 37 of Set 9 | manggar
# Processing Record 38 of Set 9 | tubarjal
# Processing Record 39 of Set 9 | polyarnyy
# Processing Record 40 of Set 9 | cardenas
# Processing Record 41 of Set 9 | massawa
# Processing Record 42 of Set 9 | surubim
# Processing Record 43 of Set 9 | kodinsk
# Processing Record 44 of Set 9 | ulverstone
# Processing Record 45 of Set 9 | fiambala
# Processing Record 46 of Set 9 | teofilo otoni
# Processing Record 47 of Set 9 | vama
# Processing Record 48 of Set 9 | atar
# Processing Record 49 of Set 9 | sao vicente
# Processing Record 0 of Set 10 | santa maria da vitoria
# Processing Record 1 of Set 10 | praia da vitoria
# Processing Record 2 of Set 10 | moussoro
# Processing Record 3 of Set 10 | gumdag
# Processing Record 4 of Set 10 | leava
# Processing Record 5 of Set 10 | sechura
# Processing Record 6 of Set 10 | kenora
# Processing Record 7 of Set 10 | priozersk
# Processing Record 8 of Set 10 | new norfolk
# Processing Record 9 of Set 10 | haiku-pauwela
# Processing Record 10 of Set 10 | koungou
# Processing Record 11 of Set 10 | birjand
# Processing Record 12 of Set 10 | tanrake village
# City not found. Skipping...
# Processing Record 13 of Set 10 | kez
# Processing Record 14 of Set 10 | albu kamal
# Processing Record 15 of Set 10 | plastun
# Processing Record 16 of Set 10 | saint-philippe
# Processing Record 17 of Set 10 | bozoum
# Processing Record 18 of Set 10 | tabas
# Processing Record 19 of Set 10 | oranjestad
# Processing Record 20 of Set 10 | cambria
# Processing Record 21 of Set 10 | amungan
# Processing Record 22 of Set 10 | dodge city
# Processing Record 23 of Set 10 | qarazhal
# Processing Record 24 of Set 10 | dangriga
# Processing Record 25 of Set 10 | iyidere
# Processing Record 26 of Set 10 | umatilla
# Processing Record 27 of Set 10 | novodvinsk
# Processing Record 28 of Set 10 | dire
# Processing Record 29 of Set 10 | corner brook
# Processing Record 30 of Set 10 | murun-kuren
# Processing Record 31 of Set 10 | lethem
# Processing Record 32 of Set 10 | pombas
# Processing Record 33 of Set 10 | kourou
# Processing Record 34 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 35 of Set 10 | grand falls-windsor
# Processing Record 36 of Set 10 | russkaya polyana
# Processing Record 37 of Set 10 | belokurikha
# Processing Record 38 of Set 10 | dongola
# Processing Record 39 of Set 10 | lorengau
# Processing Record 40 of Set 10 | yaren
# Processing Record 41 of Set 10 | mil'kovo
# Processing Record 42 of Set 10 | nguigmi
# Processing Record 43 of Set 10 | balabac
# Processing Record 44 of Set 10 | beidao
# Processing Record 45 of Set 10 | kenai
# Processing Record 46 of Set 10 | pacasmayo
# Processing Record 47 of Set 10 | harstad
# Processing Record 48 of Set 10 | olimpia
# Processing Record 49 of Set 10 | zhangjiakou
# Processing Record 0 of Set 11 | ranibennur
# Processing Record 1 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 2 of Set 11 | smithers
# Processing Record 3 of Set 11 | chui
# Processing Record 4 of Set 11 | tralee
# Processing Record 5 of Set 11 | tayshet
# Processing Record 6 of Set 11 | guiuan
# Processing Record 7 of Set 11 | liwale
# Processing Record 8 of Set 11 | namtsy
# Processing Record 9 of Set 11 | buritizeiro
# Processing Record 10 of Set 11 | joshimath
# Processing Record 11 of Set 11 | dzilam gonzalez
# Processing Record 12 of Set 11 | tual
# Processing Record 13 of Set 11 | selkirk
# Processing Record 14 of Set 11 | amursk
# Processing Record 15 of Set 11 | toliara
# Processing Record 16 of Set 11 | yakeshi
# Processing Record 17 of Set 11 | karaton
# Processing Record 18 of Set 11 | campos dos goytacazes
# Processing Record 19 of Set 11 | san
# Processing Record 20 of Set 11 | baiti
# Processing Record 21 of Set 11 | kaka
# Processing Record 22 of Set 11 | muyuka
# Processing Record 23 of Set 11 | akureyri
# Processing Record 24 of Set 11 | nova xavantina
# Processing Record 25 of Set 11 | ciudad pemex
# Processing Record 26 of Set 11 | illizi
# Processing Record 27 of Set 11 | deschutes river woods
# Processing Record 28 of Set 11 | labasa
# Processing Record 29 of Set 11 | dazhou
# Processing Record 30 of Set 11 | trairi
# Processing Record 31 of Set 11 | kamina
# Processing Record 32 of Set 11 | dunedin
# Processing Record 33 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 11 | kittila
# Processing Record 35 of Set 11 | bandrele
# Processing Record 36 of Set 11 | topolobampo
# Processing Record 37 of Set 11 | zalari
# Processing Record 38 of Set 11 | bismarck
# Processing Record 39 of Set 11 | bhuj
# Processing Record 40 of Set 11 | nizhnevartovsk
# Processing Record 41 of Set 11 | urzhar
# Processing Record 42 of Set 11 | cidreira
# Processing Record 43 of Set 11 | chimore
# Processing Record 44 of Set 11 | salalah
# Processing Record 45 of Set 11 | temirlanovka
# Processing Record 46 of Set 11 | pueblo nuevo
# Processing Record 47 of Set 11 | arteche
# Processing Record 48 of Set 11 | gotha
# Processing Record 49 of Set 11 | hammerfest
# Processing Record 0 of Set 12 | skeldon
# Processing Record 1 of Set 12 | kununurra
# Processing Record 2 of Set 12 | saint-joseph-du-lac
# Processing Record 3 of Set 12 | maqat
# Processing Record 4 of Set 12 | omdurman
# Processing Record 5 of Set 12 | thai binh
# Processing Record 6 of Set 12 | lincoln city
# Processing Record 7 of Set 12 | peace river
# Processing Record 8 of Set 12 | coxen hole
# Processing Record 9 of Set 12 | coahuayana de hidalgo
# Processing Record 10 of Set 12 | argo
# Processing Record 11 of Set 12 | labuan
# Processing Record 12 of Set 12 | hayma'
# City not found. Skipping...
# Processing Record 13 of Set 12 | beyneu
# Processing Record 14 of Set 12 | rio preto da eva
# Processing Record 15 of Set 12 | kalemie
# Processing Record 16 of Set 12 | sola
# Processing Record 17 of Set 12 | san jose del guaviare
# Processing Record 18 of Set 12 | mana
# Processing Record 19 of Set 12 | kuanda
# Processing Record 20 of Set 12 | sogndal
# Processing Record 21 of Set 12 | fale old settlement
# Processing Record 22 of Set 12 | puerto baquerizo moreno
# Processing Record 23 of Set 12 | goz beida
# Processing Record 24 of Set 12 | pamplona
# Processing Record 25 of Set 12 | ponta delgada
# Processing Record 26 of Set 12 | cooper's town
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 8 | iskateley
# Processing Record 33 of Set 8 | pariaman
# Processing Record 34 of Set 8 | okhotsk
# Processing Record 35 of Set 8 | caleta de carquin
# Processing Record 36 of Set 8 | gamboula
# Processing Record 37 of Set 8 | sitangkai
# Processing Record 38 of Set 8 | thunder bay
# Processing Record 39 of Set 8 | tanjung pinang
# Processing Record 40 of Set 8 | oranjestad
# Processing Record 41 of Set 8 | illizi
# Processing Record 42 of Set 8 | remire-montjoly
# Processing Record 43 of Set 8 | ivins
# Processing Record 44 of Set 8 | college
# Processing Record 45 of Set 8 | mohr
# Processing Record 46 of Set 8 | elverum
# Processing Record 47 of Set 8 | odda
# Processing Record 48 of Set 8 | bikenibeu village
# Processing Record 49 of Set 8 | fomboni
# Processing Record 0 of Set 9 | salalah
# Processing Record 1 of Set 9 | mejit
# Processing Record 2 of Set 9 | sosua
# Processing Record 3 of Set 9 | mogocha
# Processing Record 4 of Set 9 | kailua-kona
# Processing Record 5 of Set 9 | kabinda
# Processing Record 6 of Set 9 | satupa'itea
# City not found. Skipping...
# Processing Record 7 of Set 9 | woolgoolga
# Processing Record 8 of Set 9 | bafia
# Processing Record 9 of Set 9 | weno
# Processing Record 10 of Set 9 | abepura
# Processing Record 11 of Set 9 | sheridan
# Processing Record 12 of Set 9 | laguna
# Processing Record 13 of Set 9 | cable beach
# City not found. Skipping...
# Processing Record 14 of Set 9 | beloyarskiy
# Processing Record 15 of Set 9 | la ronge
# Processing Record 16 of Set 9 | mammoth lakes
# Processing Record 17 of Set 9 | shenjiamen
# Processing Record 18 of Set 9 | cabedelo
# Processing Record 19 of Set 9 | choibalsan
# Processing Record 20 of Set 9 | stawell
# Processing Record 21 of Set 9 | mali
# Processing Record 22 of Set 9 | carbonear
# Processing Record 23 of Set 9 | mugumu
# Processing Record 24 of Set 9 | yorkton
# Processing Record 25 of Set 9 | midvagur
# Processing Record 26 of Set 9 | la chaux-de-fonds
# Processing Record 27 of Set 9 | paradip garh
# Processing Record 28 of Set 9 | ban karon
# Processing Record 29 of Set 9 | saint joseph
# Processing Record 30 of Set 9 | manicore
# Processing Record 31 of Set 9 | el quebrachal
# Processing Record 32 of Set 9 | adrar
# Processing Record 33 of Set 9 | marion
# Processing Record 34 of Set 9 | kruisfontein
# Processing Record 35 of Set 9 | toyooka
# Processing Record 36 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 37 of Set 9 | mahina
# Processing Record 38 of Set 9 | zadar
# Processing Record 39 of Set 9 | as sulayyil
# Processing Record 40 of Set 9 | kasongo
# Processing Record 41 of Set 9 | masindi port
# Processing Record 42 of Set 9 | siwa oasis
# Processing Record 43 of Set 9 | villa la venta
# Processing Record 44 of Set 9 | ceres
# Processing Record 45 of Set 9 | port glaud
# City not found. Skipping...
# Processing Record 46 of Set 9 | lyskovo
# Processing Record 47 of Set 9 | moroni
# Processing Record 48 of Set 9 | tura
# Processing Record 49 of Set 9 | north battleford
# Processing Record 0 of Set 10 | dunoon
# Processing Record 1 of Set 10 | santa cruz
# Processing Record 2 of Set 10 | bagudo
# Processing Record 3 of Set 10 | tadine
# Processing Record 4 of Set 10 | orchard homes
# Processing Record 5 of Set 10 | ixtapa
# Processing Record 6 of Set 10 | molde
# Processing Record 7 of Set 10 | pordic
# Processing Record 8 of Set 10 | tokar
# Processing Record 9 of Set 10 | rabo de peixe
# Processing Record 10 of Set 10 | abdulino
# Processing Record 11 of Set 10 | vylkove
# Processing Record 12 of Set 10 | plastun
# Processing Record 13 of Set 10 | greymouth
# Processing Record 14 of Set 10 | yaren
# Processing Record 15 of Set 10 | vryburg
# Processing Record 16 of Set 10 | daday
# Processing Record 17 of Set 10 | kwang binh
# Processing Record 18 of Set 10 | bandundu
# Processing Record 19 of Set 10 | malindi
# Processing Record 20 of Set 10 | douglas
# Processing Record 21 of Set 10 | peace river
# Processing Record 22 of Set 10 | mana
# Processing Record 23 of Set 10 | malpe
# Processing Record 24 of Set 10 | minas de marcona
# Processing Record 25 of Set 10 | sampit
# Processing Record 26 of Set 10 | yakeshi
# Processing Record 27 of Set 10 | zaozersk
# Processing Record 28 of Set 10 | namibe
# Processing Record 29 of Set 10 | caibarien
# Processing Record 30 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 10 | port huron
# Processing Record 32 of Set 10 | meldola
# Processing Record 33 of Set 10 | hadibu
# Processing Record 34 of Set 10 | haiku-pauwela
# Processing Record 35 of Set 10 | villa gesell
# Processing Record 36 of Set 10 | le hocq
# City not found. Skipping...
# Processing Record 37 of Set 10 | tash-kumyr
# Processing Record 38 of Set 10 | aripuana
# Processing Record 39 of Set 10 | vytegra
# Processing Record 40 of Set 10 | tangjin
# Processing Record 41 of Set 10 | dunedin
# Processing Record 42 of Set 10 | barabai
# Processing Record 43 of Set 10 | ballina
# Processing Record 44 of Set 10 | quepos
# Processing Record 45 of Set 10 | cox's bazar
# Processing Record 46 of Set 10 | menomonie
# Processing Record 47 of Set 10 | aver-o-mar
# Processing Record 48 of Set 10 | sinabang
# Processing Record 49 of Set 10 | daru
# Processing Record 0 of Set 11 | acapulco de juarez
# Processing Record 1 of Set 11 | margate
# Processing Record 2 of Set 11 | vieux-habitants
# Processing Record 3 of Set 11 | mamboma
# Processing Record 4 of Set 11 | sunne
# Processing Record 5 of Set 11 | castro alves
# Processing Record 6 of Set 11 | hasaki
# Processing Record 7 of Set 11 | upata
# Processing Record 8 of Set 11 | igarka
# Processing Record 9 of Set 11 | colby
# Processing Record 10 of Set 11 | punta de bombon
# Processing Record 11 of Set 11 | arno
# Processing Record 12 of Set 11 | waingapu
# Processing Record 13 of Set 11 | yusufeli
# Processing Record 14 of Set 11 | sarandi del yi
# Processing Record 15 of Set 11 | bertoua
# Processing Record 16 of Set 11 | shajiang
# Processing Record 17 of Set 11 | calvinia
# Processing Record 18 of Set 11 | manadhoo
# Processing Record 19 of Set 11 | kununurra
# Processing Record 20 of Set 11 | kupang
# Processing Record 21 of Set 11 | guanica
# Processing Record 22 of Set 11 | whakatane
# Processing Record 23 of Set 11 | sechura
# Processing Record 24 of Set 11 | viana do castelo
# Processing Record 25 of Set 11 | yarmouth
# Processing Record 26 of Set 11 | porto velho
# Processing Record 27 of Set 11 | kouango
# Processing Record 28 of Set 11 | yoloten
# Processing Record 29 of Set 11 | lepsy
# Processing Record 30 of Set 11 | goure
# Processing Record 31 of Set 11 | arraial do cabo
# Processing Record 32 of Set 11 | ocos
# Processing Record 33 of Set 11 | caconda
# Processing Record 34 of Set 11 | brainerd
# Processing Record 35 of Set 11 | ghormach
# Processing Record 36 of Set 11 | am timan
# Processing Record 37 of Set 11 | shakawe
# Processing Record 38 of Set 11 | trenggalek
# Processing Record 39 of Set 11 | xiongzhou
# Processing Record 40 of Set 11 | guaraciaba do norte
# Processing Record 41 of Set 11 | keita
# Processing Record 42 of Set 11 | libog
# Processing Record 43 of Set 11 | shimoda
# Processing Record 44 of Set 11 | simanggang
# Processing Record 45 of Set 11 | kaya
# Processing Record 46 of Set 11 | nagtipunan
# Processing Record 47 of Set 11 | saint croix
# Processing Record 48 of Set 11 | tamiahua
# Processing Record 49 of Set 11 | banes
# Processing Record 0 of Set 12 | hannibal
# Processing Record 1 of Set 12 | nadi
# Processing Record 2 of Set 12 | vila velha
# Processing Record 3 of Set 12 | armacao de buzios
# Processing Record 4 of Set 12 | zagora
# Processing Record 5 of Set 12 | keflavik
# Processing Record 6 of Set 12 | north shore
# Processing Record 7 of Set 12 | betio village
# Processing Record 8 of Set 12 | san rafael del sur
# Processing Record 9 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 12 | burang
# Processing Record 11 of Set 12 | malpica
# Processing Record 12 of Set 12 | puerto armuelles
# Processing Record 13 of Set 12 | saint-pierre-d'oleron
# City not found. Skipping...
# Processing Record 14 of Set 12 | bocas del toro
# Processing Record 15 of Set 12 | mangrol
# Processing Record 16 of Set 12 | hiratacho
# Processing Record 17 of Set 12 | garango
# Processing Record 18 of Set 12 | coquimbo
# Processing Record 19 of Set 12 | beichengqu
# Processing Record 20 of Set 12 | da nang
# Processing Record 21 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 22 of Set 12 | kapshagay
# Processing Record 23 of Set 12 | alghero
# Processing Record 24 of Set 12 | gillette
# Processing Record 25 of Set 12 | trairi
# Processing Record 26 of Set 12 | mizhhirya
# Processing Record 27 of Set 12 | san andres
# Processing Record 28 of Set 12 | eureka
# Processing Record 29 of Set 12 | aykhal
# Processing Record 30 of Set 12 | san lawrenz
# Processing Record 31 of Set 12 | shagonar
# Processing Record 32 of Set 12 | veraval
# Processing Record 33 of Set 12 | xanthi
# Processing Record 34 of Set 12 | raton
# Processing Record 35 of Set 12 | east london
# Processing Record 36 of Set 12 | shevchenko
# Processing Record 37 of Set 12 | yerofey pavlovich
# Processing Record 38 of Set 12 | parczew
# Processing Record 39 of Set 12 | kodinsk
# Processing Record 40 of Set 12 | darhan
# Processing Record 41 of Set 12 | cockburn town
# Processing Record 42 of Set 12 | gaspe
# Processing Record 43 of Set 12 | santa cruz del sur
# Processing Record 44 of Set 12 | cedeira
# Processing Record 45 of Set 12 | porto novo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          553
# Lat           553
# Lng           553
# Max Temp      553
# Humidity      553
# Cloudiness    553
# Wind Speed    553
# Country       553
# Date          553
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     margaret river -33.9500  115.0667     20.07        78          45
# 1              tiksi  71.6872  128.8694    -29.48        98          51
# 2  port-aux-francais -49.3500   70.2167      4.34        78          64
# 3           waitangi -43.9535 -176.5597     14.34        91          73
# 4          grytviken -54.2811  -36.5092      3.57        79          24
#
#    Wind Speed Country        Date
# 0        3.32      AU  1732088697
# 1        2.23      RU  1732088697
# 2       14.51      TF  1732088697
# 3        4.02      NZ  1732088697
# 4        3.91      GS  1732088697

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           margaret river -33.9500  115.0667     20.07        78          45
# 1                    tiksi  71.6872  128.8694    -29.48        98          51
# 2        port-aux-francais -49.3500   70.2167      4.34        78          64
# 3                 waitangi -43.9535 -176.5597     14.34        91          73
# 4                grytviken -54.2811  -36.5092      3.57        79          24
#
#          Wind Speed Country        Date
# City_ID
# 0              3.32      AU  1732088697
# 1              2.23      RU  1732088697
# 2             14.51      TF  1732088697
# 3              4.02      NZ  1732088697
# 4              3.91      GS  1732088697

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# calculate date based on the median of all recorded "timestamp"
import datetime
date = city_data_df["Date"].median()
date = datetime.date.fromtimestamp(date)

# Build scatter plot for latitude vs. temperature
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Max Temp"]
plt.scatter(x_axis,y_axis, c="skyblue", edgecolors= "black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Max Temperature ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Humidity"]
plt.scatter(x_axis,y_axis, c="skyblue", edgecolors= "black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Cloudiness"]
plt.scatter(x_axis,y_axis, c="skyblue", edgecolors= "black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Wind Speed"]
plt.scatter(x_axis,y_axis, c="skyblue", edgecolors= "black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linRegPlot(x_axis, y_axis):

    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    print(f"The r value is: {rvalue}")
    
    # build scatter plot
    plt.scatter(x_axis,y_axis)
    plt.plot(x_axis,regress_values, color = "red")
    
    plt.annotate(line_eq,(x_axis.min(),y_axis.min()),fontsize=15,color="red")
    
    plt.xlabel("Latitude")
    plt.ylabel(y_axis.name)
    
    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                           tiksi  71.6872  128.8694    -29.48        98
# 6                      whitehorse  60.7161 -135.0538    -19.57        71
# 7          hawaiian paradise park  19.5933 -154.9731     22.73        97
# 8                        rahachow  53.0934   30.0495      6.49        57
# 9        petropavlovsk-kamchatsky  53.0452  158.6483     -2.67        50
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                51        2.23      RU  1732088697
# 6               100        3.60      CA  1732088698
# 7               100        1.54      US  1732088698
# 8               100        8.96      BY  1732088698
# 9                75        1.00      RU  1732088698

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           margaret river -33.9500  115.0667     20.07        78          45
# 2        port-aux-francais -49.3500   70.2167      4.34        78          64
# 3                 waitangi -43.9535 -176.5597     14.34        91          73
# 4                grytviken -54.2811  -36.5092      3.57        79          24
# 5                  irymple -34.2500  142.1667     31.16        20          51
#
#          Wind Speed Country        Date
# City_ID
# 0              3.32      AU  1732088697
# 2             14.51      TF  1732088697
# 3              4.02      NZ  1732088697
# 4              3.91      GS  1732088697
# 5              0.89      AU  1732088698

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# Define x_axis and y_axis
x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Max Temp"]

# Create Linear Regression plots
linRegPlot(x_axis, y_axis)
# Out:
# The r value is: -0.9061267409491736

# %%
# Linear regression on Southern Hemisphere

# Define x_axis and y_axis
x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Max Temp"]

# Create Linear Regression plots
linRegPlot(x_axis, y_axis)
# Out:
# The r value is: 0.6429549372018065

# %% [markdown]
# **Discussion about the linear relationship:** The r-value of the scatter plot for the Northern Hemisphere is between -0.5 and -1. The figure is close to -1.
# The r-value of the scatter plot for the Southern Hemisphere between 0.5 and 1.
# The correlation between the Latitude and Max Temperature of the cities is high.
# For Northern Hemisphere, there is high negative correlation between Latitude and Max Temperature.
# For Southern Hemisphere, there is moderately high positive correlation between Latitude and Max Temperature.
# For both the Northern and Southern Hemisphere, the closer the Latitude to 0 (the equator), the higher the max temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Define x_axis and y_axis
x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Humidity"]

# Create Linear Regression plots
linRegPlot(x_axis, y_axis)
# Out:
# The r value is: 0.2921688517734042

# %%
# Southern Hemisphere

# Define x_axis and y_axis
x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Humidity"]

# Create Linear Regression plots
linRegPlot(x_axis, y_axis)
# Out:
# The r value is: 0.1158756808639339

# %% [markdown]
# **Discussion about the linear relationship:** The r-value for scatter plot for Northern Hemisphere is between 0 and 0.5. The r-value for scatter plot for Southern Hemisphere is close to 0. The correlation between Latitude and Humidity is low.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Define x_axis and y_axis
x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Cloudiness"]

# Create Linear Regression plots
linRegPlot(x_axis, y_axis)
# Out:
# The r value is: 0.122113980440096

# %%
# Southern Hemisphere

# Define x_axis and y_axis
x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Cloudiness"]

# Create Linear Regression plots
linRegPlot(x_axis, y_axis)
# Out:
# The r value is: 0.09435793106469736

# %% [markdown]
# **Discussion about the linear relationship:** The r-values for scatter plots for both Northern Hemisphere and Southern Hemisphere are close to 0. The correlation between Latitude and Cloudiness is low.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Define x_axis and y_axis
x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Wind Speed"]

# Create Linear Regression plots
linRegPlot(x_axis, y_axis)
# Out:
# The r value is: 0.11261512202031425

# %%
# Southern Hemisphere

# Define x_axis and y_axis
x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Wind Speed"]

# Create Linear Regression plots
linRegPlot(x_axis, y_axis)
# Out:
# The r value is: -0.19514942752002

# %% [markdown]
# **Discussion about the linear relationship:** The r-values for scatter plots for both Northern Hemisphere and Southern Hemisphere are close to 0. The correlation between Latitude and Wind Speed is low.
